# %%
import pandas as pd
import numpy as np
import os
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn import linear_model
from sklearn import svm
from sklearn import metrics
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import chi2
from sklearn import cross_validation

# %%
#The data are extract from the csv files in two differents dataframe pandas
#Then the two dataframes,df_train and df_test are merged together into df_total
def csv_to_dataframe(path_general,dataset):

    path=os.path.join(path_general, 'us_census_full', dataset)
    df= pd.read_csv(path, header=0,sep=',\s', na_values=["?"],engine='python')
    df=df.drop(['instance_weight'], axis=1)
    return df

path_general="/Users/pierregagliardi/DossierTravail/Programmation/PythonPath/Us_Census"
training_set='census_income_learn.csv'
testing_set='census_income_test.csv'
df_train=csv_to_dataframe(path_general,training_set)
df_test=csv_to_dataframe(path_general,testing_set)
number_training_examples=df_train.shape[0]
#We concatenate the training set and the testing set, to do some manipulation on the whole set
df_total = pd.concat([df_train, df_test],ignore_index=True)

#Some feature have the wrong type when pandas read the csv,
#so we change features which has int64 type instead of object type
list_wrong_types=['veterans_benefits','own_business_or_self_employed','industry_recode','occupation_recode','year']
df_total[list_wrong_types]=df_total[list_wrong_types].applymap(str)

print('%d training examples\n'%df_train.shape[0])
print('%d testing examples\n'%df_test.shape[0])
print('%d features\n'%df_total.shape[1])
# Out:
# 199523 training examples
#
# 99762 testing examples
#
# 41 features

# %%
#Scaling features:
def normalized(df):
    int64Column=[c for c in df if df[c].dtype == "int64"]
    for c in int64Column:
        df.loc[:,c]=(df[int64Column]-df[int64Column].mean())/df[int64Column].std()
    return df
df_total=normalized(df_total)

# %%
# Complete missing value hispanic_origins:
df_total['hispanic_simplified']='no'
df_hispanic=df_total[['hispanic_origin','country_of_birth_self', 'country_of_birth_father','country_of_birth_mother']]

yes=['Central or South American','Mexican (Mexicano)','Mexican-American','Other Spanish','Puerto Rican','Cuban','Chicano']
hispanic_countries=['Mexico','Puerto-Rico','Ecuador','Guatemala','Nicaragua','Guatemala','Nicaragua','Cuba','Dominican-Republic','El-Salvador']


c1=df_hispanic.hispanic_origin.isin(yes)
c2=df_hispanic.country_of_birth_self.isin(hispanic_countries)
c3=df_hispanic.country_of_birth_father.isin(hispanic_countries)
c4=df_hispanic.country_of_birth_mother.isin(hispanic_countries)

df_total.loc[(c1 | c2 | c3 | c4),'hispanic_simplified']='yes'
df_total[['hispanic_simplified','hispanic_origin','country_of_birth_self', 'country_of_birth_father','country_of_birth_mother']].head(25)
# Out:
#    hispanic_simplified            hispanic_origin country_of_birth_self  \
# 0                   no                  All other         United-States
# 1                   no                  All other         United-States
# 2                   no                  All other               Vietnam
# 3                   no                  All other         United-States
# 4                   no                  All other         United-States
# 5                   no                  All other         United-States
# 6                   no                  All other         United-States
# 7                   no                  All other         United-States
# 8                   no                  All other         United-States
# 9                   no                  All other         United-States
# 10                  no                  All other         United-States
# 11                  no                  All other                   NaN
# 12                  no                Do not know         United-States
# 13                 yes  Central or South American              Columbia
# 14                  no                  All other         United-States
# 15                  no                  All other         United-States
# 16                  no                  All other         United-States
# 17                 yes         Mexican (Mexicano)                Mexico
# 18                 yes           Mexican-American         United-States
# 19                  no                  All other         United-States
# 20                 yes           Mexican-American         United-States
# 21                  no                  All other         United-States
# 22                  no                  All other         United-States
# 23                  no                  All other         United-States
# 24                  no                  All other         United-States
#
#    country_of_birth_father country_of_birth_mother
# 0            United-States           United-States
# 1            United-States           United-States
# 2                  Vietnam                 Vietnam
# 3            United-States           United-States
# 4            United-States           United-States
# 5              Philippines           United-States
# 6            United-States           United-States
# 7            United-States           United-States
# 8            United-States           United-States
# 9            United-States           United-States
# 10           United-States           United-States
# 11                     NaN                     NaN
# 12           United-States           United-States
# 13                Columbia                Columbia
# 14           United-States           United-States
# 15           United-States           United-States
# 16                 Germany           United-States
# 17                  Mexico                  Mexico
# 18           United-States             El-Salvador
# 19           United-States           United-States
# 20           United-States           United-States
# 21           United-States           United-States
# 22           United-States           United-States
# 23           United-States           United-States
# 24                   Japan           United-States

# %%
# Create new features:
df_total['total_gain']=df_total['capital_gains']-df_total['capital_losses']+df_total['dividends_from_stocks']
df_total['income']=df_total['wage_per_hour']*df_total['weeks_worked_in_year']

# %%
#Build an array of binomial number for the target
y_total= df_total['target'].map( {'- 50000.': 0, '50000+.': 1} ).astype(int).values

#Drop columns with missing values
df_total=df_total.dropna(axis = 1)

#Drop the target column class
df_total=df_total.drop(['target'], axis=1)

#Create dataframe with only continuous variable
continuousColumn=[c for c in df_total if df_total[c].dtype != "object"]
df_continuous=df_total[continuousColumn]

#Create dataframe with only nominal variable
df_nominal=df_total.drop(continuousColumn,axis=1)

print('We have drop the columns with missing values.\n')
print('There are %d continuous features\n'%len(continuousColumn))
print('There are %d nominal features \n'%(df_total.shape[1]-len(continuousColumn)))
# Out:
# We have drop the columns with missing values.
#
# There are 9 continuous features
#
# There are 25 nominal features

# %%
def dataframe_to_nparray(df):
    #Transform the pandas dataframe into a list of dictionnaries
    Listdict_feature_total=df.T.to_dict().values()

    # For each of the possible string values that the feature can take on, 
    # the vec object build a one boolean-valued feature
    vec = DictVectorizer(sparse = False)
    X=vec.fit_transform(Listdict_feature_total)
    
    return (X,vec) 

(X_total,vec_total)=dataframe_to_nparray(df_total)
(X_continuous,vec_continuous)=dataframe_to_nparray(df_continuous)
(X_nominal,vec_nominal)=dataframe_to_nparray(df_nominal)

# %%
X_train=X_total[:number_training_examples,:]
X_test=X_total[number_training_examples:,:]
y_train=y_total[:number_training_examples]
y_test=y_total[number_training_examples:]
print('There are %d features, %d one-hot-encoded features\n'%(df_total.shape[1],X_total.shape[1]))
X_test.shape, X_train.shape
# Out:
# There are 34 features, 291 one-hot-encoded features
# ((99762, 291), (199523, 291))

# %%
#Compute Anova test for continuous variables and Chi2 test for nominal variables
def score(X,y,k,vec,statistic_test):
    test = SelectKBest(statistic_test, k )
    test.fit_transform(X, y)
    
    #Enumerate the test score: [(0,test_score0),(1,test_score1)...]
    enumerate_test_scores=enumerate(test.scores_)

    #Sort the test score from greater to smaller
    ranked_features = sorted(enumerate_test_scores,key=lambda x:x[1], reverse=True)

    #Take the k features with the greatest score
    top_ranked_features=ranked_features[:k]
    top_ranked_features_indices = map(list,zip(*top_ranked_features))[0]
    
    #Retrieve features names from the vectorizer
    features_names=np.asarray(vec.get_feature_names())

    for feature_pvalue in zip(features_names[top_ranked_features_indices],test.scores_[top_ranked_features_indices],test.pvalues_[top_ranked_features_indices]):
        print feature_pvalue
        
#Anova test for continuous variables    
score(X_continuous,y_total,7,vec_continuous,f_classif)
# Out:
# ('weeks_worked_in_year', 22099.531778511238, 0.0)
# ('capital_gains', 18354.25948439791, 0.0)
# ('num_persons_worked_for_employer', 15832.132400868035, 0.0)
# ('dividends_from_stocks', 9845.2911708393294, 0.0)
# ('total_gain', 7073.1696675453077, 0.0)
# ('capital_losses', 6651.2822134114776, 0.0)
# ('age', 5666.315940942015, 0.0)

# %%
#chi2 test for nominal variables  
score(X_nominal,y_total,20,vec_nominal,chi2)

# %%
#Log-linear classifier
clf1 = linear_model.LogisticRegression(C=1e5)
clf1.fit(X_train, y_train)
y_prediction=clf1.predict(X_test)

score=metrics.accuracy_score(y_test, y_prediction)
print('The accuracy of the logistic regression model is %.4f pct'%score)
# Out:
# The accuracy of the logistic regression model is 0.9535 pct

# %%
#Plot confusion matrix

def plot_confusion_matrix(cm, title='Normalized confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(2)
    target_names=['- 50000.','50000+.']
    #rotation=45 represents the degree of rotation of the tick label
    plt.xticks(tick_marks, target_names, rotation=45)
    plt.yticks(tick_marks, target_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    #This piece of code writes the number of classified instances, in each case of the confusion matrix
    for i, cases in enumerate(cm):
        for j, case in enumerate(cases):
            if case>0:
                plt.text(j-.2, i+.2, case, fontsize=14)
    plt.show()

cm=metrics.confusion_matrix(y_test, y_prediction)
plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Reds)

# %%
#Display coefficient of the log linear model
coefs = pd.Series(clf1.coef_[0], index=vec_total.get_feature_names())
coefs.sort()
coefs.plot(kind="bar",figsize=(60,3),title='Logistic regression coefficients')

# %%
#SVM classifier with linear kernel
clf2=svm.SVC(C=1, cache_size=2000, class_weight=None,kernel='linear', max_iter=-1, probability=False, shrinking=True,tol=0.001, verbose=False)
clf2.fit(X_train, y_train)  
y_prediction2=clf2.predict(X_test)
score_svm=metrics.accuracy_score(y_test, y_prediction2)
s = pickle.dumps(clf2)
print('The accuracy of the SVM model with RBF kernel is %.4f pct'%score_svm)
